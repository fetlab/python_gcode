# %%
# %pylab
numpy.set_printoptions(suppress=True, precision=2) #suppress scientific notation
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
import thread, gcode, gclayer
from Geometry3D import Segment, Point, intersection, Renderer
from parsers import cura4
reload(thread); reload(gcode); reload(cura4); reload(gclayer)
# Out:
# <module 'gclayer' from '/Users/dan/data/projects/python_gcode/gclayer.py'>

# %%
g = gcode.GcodeFile('/Users/dan/r/thread_printer/stl/test1/main_body.gcode')

# %%
thread.layers_to_geom(g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_y/pgdchfs90b3684k57pdw_w740000gn/T/ipykernel_11188/870840790.py in <module>
# ----> 1 thread.layers_to_geom(g)
#
# ~/data/projects/python_gcode/thread.py in layers_to_geom(g, layer_height)
#      15                                 try:
#      16 					layer.geometry['segments'].append(Segment(
# ---> 17                                                         Point(last.args['X'], last.args['Y'], layer.z),
#      18 							Point(line.args['X'], line.args['Y'], layer.z)))
#      19                                 except AttributeError:
#
# ~/data/projects/open_source/geometry3D/Geometry3D/geometry/point.py in __init__(self, *args)
#      36             raise TypeError("Point() takes one or three arguments, not {}"
#      37                     .format(len(args)))
# ...

# %%
#units from fusion are always in cm, so we need to convert to mm
tpath = array(unpickle('/Users/dan/r/thread_printer/stl/test1/thread_from_fusion.pickle')) * 10
thread_transform = [131.164, 110.421, 0]
tpath += [thread_transform, thread_transform]

# %%
for s in g.layers[53].geometry:
    plot([s.start_point.x, s.end_point.x], [s.start_point.y, s.end_point.y], 'g', lw=1)
for s,e in tpath:
    plot([s[0], e[0]], [s[1], e[1]], 'r', lw=1)
axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (43.412176938962055, 191.48456300290655, 70.46100225329648, 164.50576179746207)

# %%
thread_geom2D = [Segment(Point(s[0], s[1], g.layers[53].z), Point(e[0], e[1], g.layers[53].z)) for s,e in tpath]

# %%
intersegs2D = []
for t in thread_geom:
    for s in g.layers[53].geometry:
        if intersection(t,s):
            intersegs2D.append(s)

# %%
for s in g.layers[53].geometry:
    plot([s.start_point.x, s.end_point.x], [s.start_point.y, s.end_point.y],
         'y' if s in intersegs2D else 'g', lw=1)
for s,e in tpath:
    plot([s[0], e[0]], [s[1], e[1]], 'r', lw=1)
axis('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (43.412176938962055, 191.48456300290655, 70.46100225329648, 164.50576179746207)

# %%
ax = figure().add_subplot(projection='3d')

z = g.layers[53].z
for s in g.layers[53].geometry:
    ax.plot([s.start_point.x, s.end_point.x], [s.start_point.y, s.end_point.y], [s.start_point.z, s.end_point.z], 'g', lw=1)
for s,e in tpath:
    plot([s[0], e[0]], [s[1], e[1]], [s[2], e[2]], 'r', lw=1)
    
show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
g.layers[53].geometry['planes']
# Out:
# [Plane(Point(129.435, 131.059, 11.0), Vector(0.0, 0.0, -1.0)),
#  Plane(Point(129.435, 131.059, 11.0), Vector(0.017565799353536672, 0.49024549104857335, -0.8714073681118463))]

# %%
r = Renderer()
for tg in thread_geom:
    r.add((tg, 'r', 1))
    intr1 = intersection(g.layers[53].geometry['planes'][0], tg)
    intr2 = intersection(g.layers[53].geometry['planes'][1], tg)
    #if intr1: r.add((intr1, 'g', 1))
    if intr2: r.add((intr2, 'y', 3))
r.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import plotly.graph_objects as go

fig = go.Figure()
x, y, z = [], [], []
for s in g.layers[53].geometry['segments']:
    x.extend([s.start_point.x, s.end_point.x, None])
    y.extend([s.start_point.y, s.end_point.y, None])
    z.extend([s.start_point.z, s.end_point.z, None])
fig.add_trace(go.Scatter3d(x=x, y=y, z=z, mode='lines', line={'color': 'green'}))

thread = np.vstack([tpath[:,0], tpath[:,1][-1]])
fig.add_trace(go.Scatter3d(x=thread[:,0], y=thread[:,1], z=thread[:,2], mode='lines',
                          line={'color':'red', 'dash':'dot', 'width':3}))

for tg in thread_geom:
    intr1 = intersection(g.layers[53].geometry['planes'][0], tg)
    intr2 = intersection(g.layers[53].geometry['planes'][1], tg)
    if in


"""
#Plot top/bottom planes for the layer
xx = list(filter(None, x)); yy = list(filter(None, y))
zz = g.layers[53].z - 0.2
fig.add_trace(go.Mesh3d(
    x=[min(xx), min(xx), max(xx), max(xx)],
    y=[min(yy), max(yy), max(yy), min(yy)],
    z=[zz,     zz,     zz,     zz],
    opacity=.5))
zz = g.layers[53].z + 0.2
fig.add_trace(go.Mesh3d(
    x=[min(xx), min(xx), max(xx), max(xx)],
    y=[min(yy), max(yy), max(yy), min(yy)],
    z=[zz,     zz,     zz,     zz],
    opacity=.5))
"""

fig.show()
# Out:
# <div>                            <div id="8f9d4991-d30d-4de6-bfc0-d97377c7e568" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f9d4991-d30d-4de6-bfc0-d97377c7e568")) {                    Plotly.newPlot(                        "8f9d4991-d30d-4de6-bfc0-d97377c7e568",                        [{"line":{"color":"green"},"mode":"lines","x":[129.435,130.656,null,130.656,131.884,null,131.884,133.092,null,133.092,134.255,null,134.255,135.348,null,135.348,136.348,null,136.348,137.232,null,137.232,137.983,null,137.983,138.585,null,138.585,139.023,null,139.023,139.291,null,139.291,139.381,null,139.381,139.291,null,139.291,139.023,null,139.023,138.585,null,138.585,137.983,null,137.983,137.232,null,137.232,136.347,null,136.347,135.348,null,135.348,134.255,null,1
# ...

# %%
for i,tg in enumerate(thread_geom):
    intr1 = intersection(g.layers[53].geometry['planes'][0], tg)
    intr2 = intersection(g.layers[53].geometry['planes'][1], tg)
    print(f'{i}: {intr1}, {intr2}')
# Out:
# 0: None, None
# 1: None, None
# 2: Point(149.28178306137565, 114.49404433066762, 11.0), None
# 3: None, None

# %%
g
# Out:
# <GcodeFile with 1 layers>

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches
import thread3d
# %pylab
# Out:
# Using matplotlib backend: nbAgg
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
reload(gcode)
# Out:
# <module 'gcode' from '/Users/dan/data/projects/python_gcode/gcode.py'>

# %%
reload(thread3d)
# Out:
# <module 'thread3d' from '/Users/dan/data/projects/python_gcode/thread3d.py'>

# %%
f = gcode.GcodeFile('./example_gcode/cube-prusaslicer_2.2.0.gcode', layer_class=thread3d.TLayer)
f
# Out:
# <GcodeFile with 67 layers>

# %%
l40 = f.layers[40]

# %%
l40.extents()
# Out:
# ((85.225, 85.225), (94.775, 94.775))

# %%
v = []; c = []
lines = iter(f.layers[40].lines)
l = next(lines)

#Find first location and move to it
while not(l.code in ('G0', 'G1') and ('X' in l.args or 'Y' in l.args)):
    l = next(lines)
v.append((l.args['X'], l.args['Y']))
c.append(Path.MOVETO)

for l in lines:
    if l.code in ('G0', 'G1') and ('X' in l.args or 'Y' in l.args):
        v.append((l.args['X'], l.args['Y']))
        if 'E' in l.args and l.args['E'] > 0:
            c.append(Path.LINETO)
        else:
            c.append(Path.MOVETO)

# %%
path = Path(v,c)
fig, ax = subplots()
patch = patches.PathPatch(path, fc='none', lw=2, ec='b')
ax.add_patch(patch)
xlim(84, 95)
ylim(84, 95)
ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
l40.extents()
# Out:
# (85.225, 85.225, 94.775, 94.775)

# %%
ax.set_xl
# Out:
# (84.0, 95.0)

# %%
thread3d.TLayer.plot(l40)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = gca()

# %%
ax.plot((92, 92), ax.get_ylim(), 'r', lw=.5)

# %%
thread3d.TLayer.parse_moves(l40)
# Out:
# [[[3494] G1 X85.643 Y94.357 E0.22706,
#   [3495] G1 X85.643 Y85.643 E0.22706,
#   [3496] G1 X94.357 Y85.643 E0.22706,
#   [3497] G1 X94.357 Y94.297 E0.2255],
#  [[3502] G1 X85.225 Y94.775 E0.24883,
#   [3503] G1 X85.225 Y85.225 E0.24883,
#   [3504] G1 X94.775 Y85.225 E0.24883,
#   [3506] G1 X94.775 Y94.715 E0.24727],
#  [[3519] G1 X93.586 Y89.208 E0.01356,
#   [3520] G1 X92.69 Y89.43 E0.02407,
#   [3521] G1 X92.241 Y89.376 E0.01176,
#   [3522] G1 X91.793 Y89.039 E0.01462,
#   [3523] G1 X90.897 Y87.822 E0.03938,
#   [3524] G1 X90.448 Y87.447 E0.01523,
#   [3525] G1 X90.0 Y87.206 E0.01325,
#   [3526] G1 X89.103 Y86.984 E0.02407,
#   [3527] G1 X88.655 Y87.038 E0.01176,
#   [3528] G1 X88.207 Y87.375 E0.01462,
#   [3529] G1 X87.31 Y88.592 E0.03938,
#   [3530] G1 X86.862 Y88.967 E0.01524,
#   [3531] G1 X86.414 Y89.208 E0.01325,
#   [3532] G1 X85.956 Y89.321 E0.01228,
#   [3533] G1 X85.956 Y92.546 E0.08403,
#   [3534] G1 X86.414 Y92.794 E0.01356,
#   [3535] G1 X87.31 Y93.016 E0.02407,
# ...

# %%
_70[0]

# %%
_80.get_xdata(), _80.get_ydata()
# Out:
# (array([92, 92]), array([84.225, 95.775]))

# %%
f.layers[40].plot()
# Out:
# <img src="data:image/png;base64,..." width="1280">

# %%
f.layers[40].ax.set_aspect('equal')
